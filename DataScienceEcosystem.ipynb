# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# *Explicación: El símbolo # al inicio indica encabezado de nivel 1 (H1) en Markdown.Un solo # = título principal.*

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - List commonly used Data Science libraries
# - Create a table of Data Science tools
# - Demonstrate evaluation of arithmetic expressions in Python
# - Convert minutes to hours using Python code

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# *Explicación: La primera fila es el encabezado: | Data Science Tools |, la segunda fila define la línea de separación de la cabecera: |--------------------|, las siguientes filas son las herramientas (una por fila, todas en la misma columna): Jupyter Notebook, RStudio,  Apache Zeppelin.*

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
hours = 200 / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Jose Manuel Alvarez
